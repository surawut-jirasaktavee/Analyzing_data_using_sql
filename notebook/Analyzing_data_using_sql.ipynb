# %% [markdown]
# ## Introduction

# %% [markdown]
# In this project, working with data from the CIA World Factbook, a compendium of statistics about all of the countries on Earth. The Factbook contains demographic information.

# %%
# %%capture
# %load_ext sql
# %sql sqlite:///factbook.db
# Out:
# 'Connected: None@factbook.db'

# %% [markdown]
# Introduced the name of the table and what the table looked like in the "factbook.db" database. Run the queries below to get this information directly

# %%
# %%sql
# SELECT *
#   FROM sqlite_master
#  WHERE type = 'table';
# Out:
# Done.
# [('table', 'sqlite_sequence', 'sqlite_sequence', 3, 'CREATE TABLE sqlite_sequence(name,seq)'),
#  ('table', 'facts', 'facts', 47, 'CREATE TABLE "facts" ("id" INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL, "code" varchar(255) NOT NULL, "name" varchar(255) NOT NULL, "area" integer, "a ... (4 characters truncated) ... land" integer, "area_water" integer, "population" integer, "population_growth" float, "birth_rate" float, "death_rate" float, "migration_rate" float)')]

# %% [markdown]
# For the next run the query to return information on the tables in the database and show first five rows to explore database.

# %% [markdown]
# ## Overview of the Data

# %%
# %%sql
# SELECT *
#   FROM facts
#  LIMIT 5;
# Out:
# Done.
# [(1, 'af', 'Afghanistan', 652230, 652230, 0, 32564342, 2.32, 38.57, 13.89, 1.51),
#  (2, 'al', 'Albania', 28748, 27398, 1350, 3029278, 0.3, 12.92, 6.58, 3.3),
#  (3, 'ag', 'Algeria', 2381741, 2381741, 0, 39542166, 1.84, 23.67, 4.31, 0.92),
#  (4, 'an', 'Andorra', 468, 468, 0, 85580, 0.12, 8.13, 6.96, 0.0),
#  (5, 'ao', 'Angola', 1246700, 1246700, 0, 19625353, 2.78, 38.78, 11.49, 0.46)]

# %% [markdown]
# Here are the descriptions for some of the columns:
#
#  - name --the name of the country.
#  - area --the country's total area (both land and water).
#  - area_land --the country's land area in square kilometers.
#  - area_water --the country's waterarea in square kilometers.
#  - population --the country's population.
#  - population_growth --the country's population growth as a percentage.
#  - birth_rate --the country's birth rate, or the number of births per year per 1,000 people.
#  - death_rate --the country's death rate, or the number of death per year per 1,000 people.

# %% [markdown]
# ## Summary Statistics

# %%
# %%sql
# SELECT MIN(population) AS min_pop,
#        MAX(population) AS max_pop,
#        MIN(population_growth) AS min_pop_growth,
#        MAX(population_growth) AS max_pop_growth
#   FROM facts;
# Out:
# Done.
# [(0, 7256490011, 0.0, 4.02)]

# %% [markdown]
# After summarize statistics calculation with facts table
#
#  - There's some country with population of 0.
#  - There's some country with population 7256490011 (7.2 Billion people)
#  - There's some country with population growth of 0.
#  - There's some country with population growth of 4.02

# %% [markdown]
# ## Exploring Outliers

# %%
# %%sql
# SELECT name, population, birth_rate, death_rate
#   FROM facts
#  WHERE population = (SELECT MIN(population)
#                        FROM facts);
# Out:
# Done.
# [('Antarctica', 0, None, None)]

# %% [markdown]
# Try to figure out what the country that have 0 population and finally found that country is 'Antarctica'!!

# %%
# %%sql
# SELECT name, population, birth_rate, death_rate
#   FROM facts
#  WHERE population = (SELECT MAX(population)
#                        FROM facts);
# Out:
# Done.
# [('World', 7256490011, 18.6, 7.8)]

# %% [markdown]
# And try to figure out what the country that have 7.2+ Billion people and found that country is the total result from the whole world!!
#
# Now that we know this, we should recalculate the summary statistics we calculated earlier, while excluding the row for the whole world.

# %% [markdown]
# ## Summary Statistics Revisited

# %%
# %%sql
# SELECT MIN(population),
#        MAX(population),
#        MIN(population_growth),
#        MAX(population_growth)
#   FROM facts
#  WHERE name <> 'World';
# Out:
# Done.
# [(0, 1367485388, 0.0, 4.02)]

# %% [markdown]
# There's a country whose population closes in on 1.4 billion!

# %%
# %%sql
# SELECT name
#   FROM facts
#  WHERE population = (SELECT MAX(population)
#                        FROM facts
#                       WHERE name <> 'World');
# Out:
# Done.
# [('China',)]

# %% [markdown]
# Ofcourse, China is the answer!

# %% [markdown]
# ## Exploring Average Population and Area

# %% [markdown]
# Let's explore density. Density depends on the population and the country's area. Let's look at the average values for these two columns.

# %%
# %%sql
# -- Find out the average of population and the country's area
# SELECT ROUND(AVG(population), 2) AS avg_pop,
#        ROUND(AVG(area), 2) AS avg_area
#   FROM facts
#  WHERE name <> 'World';
# Out:
# Done.
# [(32242666.57, 555093.55)]

# %%
# %%sql
# /* 1) Find out the country that have the population is above average.
#    2) Find out the country that have the area is below average.
# */
#
# SELECT *
#   FROM facts
#  WHERE population > (SELECT AVG(population)
#                        FROM facts
#                       WHERE name <> 'World'
#                     )
#
#    AND area < (SELECT AVG(area)
#                  FROM facts
#                 WHERE name <> 'World'
#               );
#  LIMIT 10
# Out:
# Done.
# (sqlite3.OperationalError) near "LIMIT": syntax error
# [SQL: LIMIT 10]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %% [markdown]
# These country in the table above is the country that have density from both the number of population and number of country's area.
#
# But, Actually need to recalculate with the "area_land" column with the other way and the people live in the land area not water area.

# %%
# %%sql
# SELECT name, population, area_land,
#        population / area_land AS pop_per_area
#   FROM facts
#  WHERE name <> 'World'
#  ORDER BY pop_per_area DESC;
# Out:
# Done.
# [('Macau', 592731, 28, 21168),
#  ('Monaco', 30535, 2, 15267),
#  ('Singapore', 5674472, 687, 8259),
#  ('Hong Kong', 7141106, 1073, 6655),
#  ('Gaza Strip', 1869055, 360, 5191),
#  ('Gibraltar', 29258, 6, 4876),
#  ('Bahrain', 1346613, 760, 1771),
#  ('Maldives', 393253, 298, 1319),
#  ('Malta', 413965, 316, 1310),
#  ('Bermuda', 70196, 54, 1299),
#  ('Bangladesh', 168957745, 130170, 1297),
#  ('Sint Maarten', 39689, 34, 1167),
#  ('Guernsey', 66080, 78, 847),
#  ('Jersey', 97294, 116, 838),
#  ('Taiwan', 23415126, 32260, 725),
#  ('Barbados', 290604, 430, 675),
#  ('Mauritius', 1339827, 2030, 660),
#  ('Aruba', 112162, 180, 623),
#  ('Lebanon', 6184701, 10230, 604),
#  ('Saint Martin', 31754, 54, 588),
#  ('San Marino', 33020, 61, 541),
#  ('Rwanda', 12661733, 24668, 513),
#  ('Korea, South', 49115196, 96920, 506),
#  ('Netherlands', 16947904, 33893, 500),
#  ('West Bank', 2785366, 5640, 493),
#  ('Nauru', 9540, 21, 454),
#  ('India', 1251695584, 2973193, 420),
#  ('Burundi', 10742276, 25680, 418),
#  ('Tuvalu', 10869, 26, 418),
#  ('Puerto Rico', 3598357, 8870, 405),
#  ('Marshall Islands', 72191, 181, 398),
#  ('Israel', 8049314, 20330, 395),
#  ('Belgium', 11323973, 30278, 374),
#  ('Haiti', 10110019, 27560, 366),
#  ('Comoros', 780971, 2235, 349),
#  ('Japan', 126919659, 364485, 348),
#  ('Sri Lanka', 22053488, 64630, 341),
#  ('Philippines', 100998376, 298170, 338),
#  ('Curacao', 148406, 444, 334),
#  ('Grenada', 110694, 344, 321),
#  ('Vietnam', 94348835, 310070, 304),
#  ('Virgin Islands', 103574, 346, 299),
#  ('Guam', 161785, 544, 297),
#  ('El Salvador', 6141350, 20721, 296),
#  ('American Samoa', 54343, 199, 273),
#  ('Jamaica', 2950210, 10831, 272),
#  ('Saint Lucia', 163922, 606, 270),
#  ('United Kingdom', 64088222, 241930, 264),
#  ('Saint Vincent and the Grenadines', 102627, 389, 263),
#  ('Pakistan', 199085847, 770875, 258),
#  ('Trinidad and Tobago', 1222363, 5128, 238),
#  ('Liechtenstein', 37624, 160, 235),
#  ('Germany', 80854408, 348672, 231),
#  ('British Virgin Islands', 33454, 151, 221),
#  ('Luxembourg', 570252, 2586, 220),
#  ('Nepal', 31551305, 143351, 220),
#  ('Dominican Republic', 10478756, 48320, 216),
#  ('Cayman Islands', 56092, 264, 212),
#  ('Italy', 61855120, 294140, 210),
#  ('Antigua and Barbuda', 92436, 442, 209),
#  ('Korea, North', 24983205, 120408, 207),
#  ('Seychelles', 92430, 455, 203),
#  ('Switzerland', 8121830, 39997, 203),
#  ('Sao Tome and Principe', 194006, 964, 201),
#  ('Nigeria', 181562056, 910768, 199),
#  ('Saint Kitts and Nevis', 51936, 261, 198),
#  ('Gambia, The', 1967709, 10120, 194),
#  ('Malawi', 17964697, 94080, 190),
#  ('Qatar', 2194817, 11586, 189),
#  ('Uganda', 37101745, 197100, 188),
#  ('Andorra', 85580, 468, 182),
#  ('Anguilla', 16418, 91, 180),
#  ('Kosovo', 1870981, 10887, 171),
#  ('Kuwait', 2788534, 17818, 156),
#  ('Isle of Man', 87545, 572, 153),
#  ('Micronesia, Federated States of', 105216, 702, 149),
#  ('Tonga', 106501, 717, 148),
#  ('China', 1367485388, 9326410, 146),
#  ('Indonesia', 255993674, 1811569, 141),
#  ('Guatemala', 14918999, 107159, 139),
#  ('Togo', 7552318, 54385, 138),
#  ('Czech Republic', 10644842, 77247, 137),
#  ('Cabo Verde', 545993, 4033, 135),
#  ('Thailand', 67976405, 510890, 133),
#  ('Denmark', 5581503, 42434, 131),
#  ('Kiribati', 105711, 811, 130),
#  ('Cyprus', 1189197, 9241, 128),
#  ('Poland', 38562189, 304255, 126),
#  ('Azerbaijan', 9780780, 82629, 118),
#  ('Portugal', 10825309, 91470, 118),
#  ('Ghana', 26327649, 227533, 115),
#  ('Slovakia', 5445027, 48105, 113),
#  ('Northern Mariana Islands', 52344, 464, 112),
#  ('Tokelau', 1337, 12, 111),
#  ('Albania', 3029278, 27398, 110),
#  ('Hungary', 9897541, 89608, 110),
#  ('Wallis and Futuna', 15613, 142, 109),
#  ('Armenia', 3056382, 28203, 108),
#  ('Moldova', 3546847, 32891, 107),
#  ('Austria', 8665550, 82445, 105),
#  ('France', 66553766, 640427, 103),
#  ('Turkey', 79414269, 769632, 103),
#  ('Cuba', 11031433, 109820, 100),
#  ('Dominica', 73607, 751, 98),
#  ('Slovenia', 1983412, 20151, 98),
#  ('Spain', 48146134, 498980, 96),
#  ('Benin', 10448647, 110622, 94),
#  ('Costa Rica', 4814144, 51060, 94),
#  ('Romania', 21666350, 229891, 94),
#  ('Malaysia', 30513848, 328657, 92),
#  ('Serbia', 7176794, 77474, 92),
#  ('Syria', 17064854, 183630, 92),
#  ('Jordan', 8117564, 88802, 91),
#  ('Cambodia', 15708756, 176515, 88),
#  ('Egypt', 88487396, 995450, 88),
#  ('Burma', 56320206, 653508, 86),
#  ('Iraq', 37056169, 437367, 84),
#  ('Swaziland', 1435613, 17204, 83),
#  ('Greece', 10775643, 130647, 82),
#  ('Macedonia', 2096015, 25433, 82),
#  ('Sierra Leone', 5879098, 71620, 82),
#  ('Timor-Leste', 1231116, 14874, 82),
#  ('Brunei', 429646, 5265, 81),
#  ('Kenya', 45925301, 569140, 80),
#  ('Croatia', 4464844, 55974, 79),
#  ('Honduras', 8746673, 111890, 78),
#  ('Ukraine', 44429471, 579330, 76),
#  ('Bosnia and Herzegovina', 3867055, 51187, 75),
#  ('Morocco', 33322699, 446300, 74),
#  ("Cote d'Ivoire", 23295302, 318003, 73),
#  ('French Polynesia', 282703, 3827, 73),
#  ('Senegal', 13975834, 192530, 72),
#  ('Ireland', 4892305, 68883, 71),
#  ('Tunisia', 11037225, 155360, 71),
#  ('Georgia', 4931226, 69700, 70),
#  ('Samoa', 197773, 2821, 70),
#  ('Burkina Faso', 18931686, 273800, 69),
#  ('United Arab Emirates', 5779760, 83600, 69),
#  ('Uzbekistan', 29199942, 425400, 68),
#  ('Bulgaria', 7186893, 108489, 66),
#  ('Eritrea', 6527689, 101000, 64),
#  ('Lesotho', 1947701, 30355, 64),
#  ('Saint Helena, Ascension, and Tristan da Cunha', 7795, 122, 63),
#  ('Mexico', 121736809, 1943945, 62),
#  ('Guinea-Bissau', 1726170, 28120, 61),
#  ('Norfolk Island', 2210, 36, 61),
#  ('Ecuador', 15868396, 276841, 57),
#  ('Tajikistan', 8191958, 141510, 57),
#  ('Tanzania', 51045882, 885800, 57),
#  ('Iran', 81824270, 1531595, 53),
#  ('Turks and Caicos Islands', 50280, 948, 53),
#  ('Montserrat', 5241, 102, 51),
#  ('Cameroon', 23739218, 472710, 50),
#  ('Yemen', 26737317, 527968, 50),
#  ('Afghanistan', 32564342, 652230, 49),
#  ('Fiji', 909389, 18274, 49),
#  ('Nicaragua', 5907881, 119990, 49),
#  ('Panama', 3657024, 74340, 49),
#  ('Montenegro', 647073, 13452, 48),
#  ('Belarus', 9589689, 202900, 47),
#  ('Guinea', 11780162, 245717, 47),
#  ('Lithuania', 2884433, 62680, 46),
#  ('Palau', 21265, 459, 46),
#  ('Colombia', 46736728, 1038700, 44),
#  ('South Africa', 53675563, 1214470, 44),
#  ('Liberia', 4195666, 96320, 43),
#  ('Cocos (Keeling) Islands', 596, 14, 42),
#  ('Cook Islands', 9838, 236, 41),
#  ('Madagascar', 23812681, 581540, 40),
#  ('Zimbabwe', 14229541, 386847, 36),
#  ('Faroe Islands', 50196, 1393, 36),
#  ('Congo, Democratic Republic of the', 79375136, 2267048, 35),
#  ('Djibouti', 828324, 23180, 35),
#  ('United States', 321368864, 9161966, 35),
#  ('Venezuela', 29275460, 882050, 33),
#  ('Bahamas, The', 324597, 10010, 32),
#  ('Mozambique', 25303113, 786380, 32),
#  ('Latvia', 1986705, 62249, 31),
#  ('Estonia', 1265420, 42388, 29),
#  ('Kyrgyzstan', 5664939, 191801, 29),
#  ('Laos', 6911544, 230800, 29),
#  ('Equatorial Guinea', 740743, 28051, 26),
#  ('Brazil', 204259812, 8358140, 24),
#  ('Chile', 17508260, 743812, 23),
#  ('Peru', 30444999, 1279996, 23),
#  ('Sweden', 9801616, 410335, 23),
#  ('Saint Pierre and Miquelon', 5657, 242, 23),
#  ('Solomon Islands', 622469, 27986, 22),
#  ('Vanuatu', 272264, 12189, 22),
#  ('Zambia', 15066266, 743398, 20),
#  ('Bhutan', 741919, 38394, 19),
#  ('Uruguay', 3341893, 175015, 19),
#  ('Finland', 5476922, 303815, 18),
#  ('Norway', 5207689, 304282, 17),
#  ('Paraguay', 6783272, 397302, 17),
#  ('Algeria', 39542166, 2381741, 16),
#  ('New Zealand', 4438393, 267710, 16),
#  ('Somalia', 10616380, 627337, 16),
#  ('Angola', 19625353, 1246700, 15),
#  ('Argentina', 43431886, 2736690, 15),
#  ('Belize', 347369, 22806, 15),
#  ('Niger', 18045729, 1266700, 14),
#  ('Papua New Guinea', 6672429, 452860, 14),
#  ('New Caledonia', 271615, 18275, 14),
#  ('Congo, Republic of the', 4755097, 341500, 13),
#  ('Mali', 16955536, 1220190, 13),
#  ('Saudi Arabia', 27752316, 2149690, 12),
#  ('Turkmenistan', 5231422, 469930, 11),
#  ('Christmas Island', 1530, 135, 11),
#  ('Oman', 3286936, 309500, 10),
#  ('Bolivia', 10800882, 1083301, 9),
#  ('Chad', 11631456, 1259200, 9),
#  ('Central African Republic', 5391539, 622984, 8),
#  ('Russia', 142423773, 16377742, 8),
#  ('Gabon', 1705336, 257667, 6),
#  ('Kazakhstan', 18157122, 2699700, 6),
#  ('Niue', 1190, 260, 4),
#  ('Botswana', 2182719, 566730, 3),
#  ('Canada', 35099836, 9093507, 3),
#  ('Guyana', 735222, 196849, 3),
#  ('Iceland', 331918, 100250, 3),
#  ('Libya', 6411776, 1759540, 3),
#  ('Mauritania', 3596702, 1030700, 3),
#  ('Suriname', 579633, 156000, 3),
#  ('Australia', 22751014, 7682300, 2),
#  ('Namibia', 2212307, 823290, 2),
#  ('Western Sahara', 570866, 266000, 2),
#  ('Mongolia', 2992908, 1553556, 1),
#  ('Pitcairn Islands', 48, 47, 1),
#  ('Greenland', 57733, 2166086, 0),
#  ('Svalbard', 1872, 62045, 0),
#  ('Falkland Islands (Islas Malvinas)', 3361, 12173, 0),
#  ('Antarctica', 0, 280000, 0),
#  ('Ethiopia', 99465819, None, None),
#  ('South Sudan', 12042910, None, None),
#  ('Sudan', 36108853, None, None),
#  ('Holy See (Vatican City)', 842, 0, None),
#  ('European Union', 513949445, None, None),
#  ('Ashmore and Cartier Islands', None, 5, None),
#  ('Coral Sea Islands', None, 3, None),
#  ('Heard Island and McDonald Islands', None, 412, None),
#  ('Clipperton Island', None, 6, None),
#  ('French Southern and Antarctic Lands', None, None, None),
#  ('Saint Barthelemy', 7237, None, None),
#  ('Bouvet Island', None, 49, None),
#  ('Jan Mayen', None, 377, None),
#  ('Akrotiri', 15700, None, None),
#  ('British Indian Ocean Territory', None, 60, None),
#  ('Dhekelia', 15700, None, None),
#  ('South Georgia and South Sandwich Islands', None, 3903, None),
#  ('Navassa Island', None, 5, None),
#  ('Wake Island', None, 6, None),
#  ('United States Pacific Island Wildlife Refuges', None, None, None),
#  ('Paracel Islands', None, 7, None),
#  ('Spratly Islands', None, 5, None),
#  ('Arctic Ocean', None, None, None),
#  ('Atlantic Ocean', None, None, None),
#  ('Indian Ocean', None, None, None),
#  ('Pacific Ocean', None, None, None),
#  ('Southern Ocean', None, None, None)]

# %% [markdown]
# Figure out that "Macau" is the country that have the most density population per land area and "Monaco", "Singapore" and "Hong Kong" respectively.

# %% [markdown]
# ## Exploring which country have the highest growth rate

# %%
# %%sql
# SELECT name, population_growth
#   FROM facts
#  WHERE name <> 'World'
#  ORDER BY population_growth DESC;
# Out:
# Done.
# [('South Sudan', 4.02),
#  ('Malawi', 3.32),
#  ('Burundi', 3.28),
#  ('Niger', 3.25),
#  ('Uganda', 3.24),
#  ('Qatar', 3.07),
#  ('Burkina Faso', 3.03),
#  ('Mali', 2.98),
#  ('Cook Islands', 2.95),
#  ('Iraq', 2.93),
#  ('Ethiopia', 2.89),
#  ('Zambia', 2.88),
#  ('Western Sahara', 2.82),
#  ('Gaza Strip', 2.81),
#  ('Tanzania', 2.79),
#  ('Angola', 2.78),
#  ('Benin', 2.78),
#  ('Togo', 2.69),
#  ('Guinea', 2.63),
#  ('Cameroon', 2.59),
#  ('Madagascar', 2.58),
#  ('United Arab Emirates', 2.58),
#  ('Rwanda', 2.56),
#  ('Equatorial Guinea', 2.51),
#  ('Liberia', 2.47),
#  ('Yemen', 2.47),
#  ('Congo, Democratic Republic of the', 2.45),
#  ('Mozambique', 2.45),
#  ('Nigeria', 2.45),
#  ('Senegal', 2.45),
#  ('Timor-Leste', 2.42),
#  ('Bahrain', 2.41),
#  ('Sierra Leone', 2.35),
#  ('Afghanistan', 2.32),
#  ('British Virgin Islands', 2.32),
#  ('Turks and Caicos Islands', 2.3),
#  ('Eritrea', 2.25),
#  ('Libya', 2.23),
#  ('Mauritania', 2.23),
#  ('Zimbabwe', 2.21),
#  ('Djibouti', 2.2),
#  ('Ghana', 2.18),
#  ('Northern Mariana Islands', 2.18),
#  ('Gambia, The', 2.16),
#  ('Central African Republic', 2.13),
#  ('Luxembourg', 2.13),
#  ('Cayman Islands', 2.1),
#  ('Oman', 2.07),
#  ('Anguilla', 2.03),
#  ('Solomon Islands', 2.02),
#  ('Congo, Republic of the', 2.0),
#  ('Vanuatu', 1.95),
#  ('West Bank', 1.95),
#  ('Gabon', 1.93),
#  ('Kenya', 1.93),
#  ("Cote d'Ivoire", 1.91),
#  ('Guinea-Bissau', 1.91),
#  ('Chad', 1.89),
#  ('Singapore', 1.89),
#  ('Belize', 1.87),
#  ('Algeria', 1.84),
#  ('Sao Tome and Principe', 1.84),
#  ('Somalia', 1.83),
#  ('Guatemala', 1.82),
#  ('Egypt', 1.79),
#  ('Nepal', 1.79),
#  ('Papua New Guinea', 1.78),
#  ('Comoros', 1.77),
#  ('Sudan', 1.72),
#  ('Tajikistan', 1.71),
#  ('Honduras', 1.68),
#  ('Marshall Islands', 1.66),
#  ('Brunei', 1.62),
#  ('Kuwait', 1.62),
#  ('Philippines', 1.61),
#  ('Bangladesh', 1.6),
#  ('Cambodia', 1.58),
#  ('Bolivia', 1.56),
#  ('Israel', 1.56),
#  ('Laos', 1.55),
#  ('Sint Maarten', 1.51),
#  ('Pakistan', 1.46),
#  ('Saudi Arabia', 1.46),
#  ('Malaysia', 1.44),
#  ('Cyprus', 1.43),
#  ('Venezuela', 1.39),
#  ('New Caledonia', 1.38),
#  ('Cabo Verde', 1.36),
#  ('Ecuador', 1.35),
#  ('South Africa', 1.33),
#  ('Aruba', 1.33),
#  ('Panama', 1.32),
#  ('Mongolia', 1.31),
#  ('Turkey', 1.26),
#  ('Ireland', 1.25),
#  ('Antigua and Barbuda', 1.24),
#  ('Dominican Republic', 1.23),
#  ('Costa Rica', 1.22),
#  ('India', 1.22),
#  ('Botswana', 1.21),
#  ('Iceland', 1.21),
#  ('Iran', 1.2),
#  ('Mexico', 1.18),
#  ('Haiti', 1.17),
#  ('Paraguay', 1.16),
#  ('Kiribati', 1.15),
#  ('Kazakhstan', 1.14),
#  ('Turkmenistan', 1.14),
#  ('Norway', 1.13),
#  ('Bhutan', 1.11),
#  ('Kyrgyzstan', 1.11),
#  ('Swaziland', 1.11),
#  ('Christmas Island', 1.11),
#  ('Suriname', 1.08),
#  ('Saint Pierre and Miquelon', 1.08),
#  ('Australia', 1.07),
#  ('Latvia', 1.06),
#  ('Colombia', 1.04),
#  ('Lithuania', 1.04),
#  ('Moldova', 1.03),
#  ('Burma', 1.01),
#  ('Morocco', 1.0),
#  ('Nicaragua', 1.0),
#  ('Peru', 0.97),
#  ('Vietnam', 0.97),
#  ('Azerbaijan', 0.96),
#  ('French Polynesia', 0.94),
#  ('Argentina', 0.93),
#  ('Uzbekistan', 0.93),
#  ('Indonesia', 0.92),
#  ('Spain', 0.89),
#  ('Tunisia', 0.89),
#  ('Lebanon', 0.86),
#  ('Bahamas, The', 0.85),
#  ('Liechtenstein', 0.84),
#  ('Sri Lanka', 0.84),
#  ('Jordan', 0.83),
#  ('Seychelles', 0.83),
#  ('Chile', 0.82),
#  ('New Zealand', 0.82),
#  ('San Marino', 0.82),
#  ('Tuvalu', 0.82),
#  ('Sweden', 0.8),
#  ('Macau', 0.8),
#  ('Jersey', 0.8),
#  ('United States', 0.78),
#  ('Brazil', 0.77),
#  ('Belgium', 0.76),
#  ('Saint Kitts and Nevis', 0.76),
#  ('Isle of Man', 0.76),
#  ('Canada', 0.75),
#  ('Switzerland', 0.71),
#  ('Jamaica', 0.68),
#  ('Fiji', 0.67),
#  ('Mauritius', 0.64),
#  ('Ukraine', 0.6),
#  ('Puerto Rico', 0.6),
#  ('Namibia', 0.59),
#  ('Virgin Islands', 0.59),
#  ('Bulgaria', 0.58),
#  ('Samoa', 0.58),
#  ('Austria', 0.55),
#  ('Estonia', 0.55),
#  ('Nauru', 0.55),
#  ('United Kingdom', 0.54),
#  ('Guam', 0.54),
#  ('Korea, North', 0.53),
#  ('Faroe Islands', 0.51),
#  ('Bermuda', 0.5),
#  ('Montserrat', 0.5),
#  ('Grenada', 0.48),
#  ('Micronesia, Federated States of', 0.46),
#  ('Serbia', 0.46),
#  ('China', 0.45),
#  ('France', 0.43),
#  ('Curacao', 0.43),
#  ('Montenegro', 0.42),
#  ('Netherlands', 0.41),
#  ('Finland', 0.4),
#  ('Palau', 0.38),
#  ('Hong Kong', 0.38),
#  ('Saint Lucia', 0.34),
#  ('Thailand', 0.34),
#  ('Guernsey', 0.34),
#  ('Wallis and Futuna', 0.33),
#  ('Lesotho', 0.32),
#  ('Barbados', 0.31),
#  ('Malta', 0.31),
#  ('Albania', 0.3),
#  ('Romania', 0.3),
#  ('American Samoa', 0.3),
#  ('Saint Vincent and the Grenadines', 0.28),
#  ('Italy', 0.27),
#  ('Uruguay', 0.27),
#  ('Slovenia', 0.26),
#  ('El Salvador', 0.25),
#  ('European Union', 0.25),
#  ('Gibraltar', 0.24),
#  ('Saint Helena, Ascension, and Tristan da Cunha', 0.24),
#  ('Taiwan', 0.23),
#  ('Denmark', 0.22),
#  ('Hungary', 0.22),
#  ('Dominica', 0.21),
#  ('Belarus', 0.2),
#  ('Macedonia', 0.2),
#  ('Germany', 0.17),
#  ('Czech Republic', 0.16),
#  ('Japan', 0.16),
#  ('Syria', 0.16),
#  ('Armenia', 0.15),
#  ('Cuba', 0.15),
#  ('Korea, South', 0.14),
#  ('Bosnia and Herzegovina', 0.13),
#  ('Croatia', 0.13),
#  ('Trinidad and Tobago', 0.13),
#  ('Andorra', 0.12),
#  ('Monaco', 0.12),
#  ('Poland', 0.09),
#  ('Portugal', 0.09),
#  ('Georgia', 0.08),
#  ('Maldives', 0.08),
#  ('Russia', 0.04),
#  ('Tonga', 0.03),
#  ('Niue', 0.03),
#  ('Svalbard', 0.03),
#  ('Guyana', 0.02),
#  ('Slovakia', 0.02),
#  ('Greece', 0.01),
#  ('Norfolk Island', 0.01),
#  ('Tokelau', 0.01),
#  ('Falkland Islands (Islas Malvinas)', 0.01),
#  ('Holy See (Vatican City)', 0.0),
#  ('Cocos (Keeling) Islands', 0.0),
#  ('Greenland', 0.0),
#  ('Pitcairn Islands', 0.0),
#  ('Kosovo', None),
#  ('Ashmore and Cartier Islands', None),
#  ('Coral Sea Islands', None),
#  ('Heard Island and McDonald Islands', None),
#  ('Clipperton Island', None),
#  ('French Southern and Antarctic Lands', None),
#  ('Saint Barthelemy', None),
#  ('Saint Martin', None),
#  ('Bouvet Island', None),
#  ('Jan Mayen', None),
#  ('Akrotiri', None),
#  ('British Indian Ocean Territory', None),
#  ('Dhekelia', None),
#  ('South Georgia and South Sandwich Islands', None),
#  ('Navassa Island', None),
#  ('Wake Island', None),
#  ('United States Pacific Island Wildlife Refuges', None),
#  ('Antarctica', None),
#  ('Paracel Islands', None),
#  ('Spratly Islands', None),
#  ('Arctic Ocean', None),
#  ('Atlantic Ocean', None),
#  ('Indian Ocean', None),
#  ('Pacific Ocean', None),
#  ('Southern Ocean', None)]

# %% [markdown]
# Figure out that "South Sudan" is the country that have to most population growth rate that found in the earlier queries.
#
# Let's find which country will add the most people to thier populations next year?

# %%
# %%sql
# SELECT name, population, population_growth,
#        population * population_growth AS next_year_pop
#   FROM facts
#  WHERE name <> 'World'
#  ORDER BY next_year_pop DESC;
# Out:
# Done.
# [('India', 1251695584, 1.22, 1527068612.48),
#  ('China', 1367485388, 0.45, 615368424.6),
#  ('Nigeria', 181562056, 2.45, 444827037.20000005),
#  ('Pakistan', 199085847, 1.46, 290665336.62),
#  ('Ethiopia', 99465819, 2.89, 287456216.91),
#  ('Bangladesh', 168957745, 1.6, 270332392.0),
#  ('United States', 321368864, 0.78, 250667713.92000002),
#  ('Indonesia', 255993674, 0.92, 235514180.08),
#  ('Congo, Democratic Republic of the', 79375136, 2.45, 194469083.20000002),
#  ('Philippines', 100998376, 1.61, 162607385.36),
#  ('Egypt', 88487396, 1.79, 158392438.84),
#  ('Brazil', 204259812, 0.77, 157280055.24),
#  ('Mexico', 121736809, 1.18, 143649434.62),
#  ('Tanzania', 51045882, 2.79, 142418010.78),
#  ('European Union', 513949445, 0.25, 128487361.25),
#  ('Uganda', 37101745, 3.24, 120209653.80000001),
#  ('Iraq', 37056169, 2.93, 108574575.17),
#  ('Turkey', 79414269, 1.26, 100061978.94),
#  ('Iran', 81824270, 1.2, 98189124.0),
#  ('Vietnam', 94348835, 0.97, 91518369.95),
#  ('Kenya', 45925301, 1.93, 88635830.92999999),
#  ('Afghanistan', 32564342, 2.32, 75549273.44),
#  ('Algeria', 39542166, 1.84, 72757585.44),
#  ('South Africa', 53675563, 1.33, 71388498.79),
#  ('Yemen', 26737317, 2.47, 66041172.99),
#  ('Sudan', 36108853, 1.72, 62107227.16),
#  ('Mozambique', 25303113, 2.45, 61992626.85),
#  ('Cameroon', 23739218, 2.59, 61484574.62),
#  ('Madagascar', 23812681, 2.58, 61436716.980000004),
#  ('Malawi', 17964697, 3.32, 59642794.04),
#  ('Niger', 18045729, 3.25, 58648619.25),
#  ('Ghana', 26327649, 2.18, 57394274.82000001),
#  ('Burkina Faso', 18931686, 3.03, 57363008.58),
#  ('Burma', 56320206, 1.01, 56883408.06),
#  ('Nepal', 31551305, 1.79, 56476835.95),
#  ('Angola', 19625353, 2.78, 54558481.339999996),
#  ('Mali', 16955536, 2.98, 50527497.28),
#  ('Colombia', 46736728, 1.04, 48606197.120000005),
#  ('South Sudan', 12042910, 4.02, 48412498.199999996),
#  ("Cote d'Ivoire", 23295302, 1.91, 44494026.82),
#  ('Malaysia', 30513848, 1.44, 43939941.12),
#  ('Zambia', 15066266, 2.88, 43390846.08),
#  ('Spain', 48146134, 0.89, 42850059.26),
#  ('Venezuela', 29275460, 1.39, 40692889.4),
#  ('Saudi Arabia', 27752316, 1.46, 40518381.36),
#  ('Argentina', 43431886, 0.93, 40391653.980000004),
#  ('Burundi', 10742276, 3.28, 35234665.28),
#  ('United Kingdom', 64088222, 0.54, 34607639.88),
#  ('Senegal', 13975834, 2.45, 34240793.300000004),
#  ('Morocco', 33322699, 1.0, 33322699.0),
#  ('Rwanda', 12661733, 2.56, 32414036.48),
#  ('Zimbabwe', 14229541, 2.21, 31447285.61),
#  ('Guinea', 11780162, 2.63, 30981826.06),
#  ('Peru', 30444999, 0.97, 29531649.029999997),
#  ('Benin', 10448647, 2.78, 29047238.659999996),
#  ('France', 66553766, 0.43, 28618119.38),
#  ('Uzbekistan', 29199942, 0.93, 27155946.060000002),
#  ('Guatemala', 14918999, 1.82, 27152578.18),
#  ('Ukraine', 44429471, 0.6, 26657682.599999998),
#  ('Canada', 35099836, 0.75, 26324877.0),
#  ('Cambodia', 15708756, 1.58, 24819834.48),
#  ('Australia', 22751014, 1.07, 24343584.98),
#  ('Thailand', 67976405, 0.34, 23111977.700000003),
#  ('Chad', 11631456, 1.89, 21983451.84),
#  ('Ecuador', 15868396, 1.35, 21422334.6),
#  ('Kazakhstan', 18157122, 1.14, 20699119.08),
#  ('Togo', 7552318, 2.69, 20315735.419999998),
#  ('Japan', 126919659, 0.16, 20307145.44),
#  ('Somalia', 10616380, 1.83, 19427975.400000002),
#  ('Sri Lanka', 22053488, 0.84, 18524929.919999998),
#  ('Bolivia', 10800882, 1.56, 16849375.92),
#  ('Italy', 61855120, 0.27, 16700882.4),
#  ('United Arab Emirates', 5779760, 2.58, 14911780.8),
#  ('Honduras', 8746673, 1.68, 14694410.639999999),
#  ('Eritrea', 6527689, 2.25, 14687300.25),
#  ('Chile', 17508260, 0.82, 14356773.2),
#  ('Libya', 6411776, 2.23, 14298260.48),
#  ('Tajikistan', 8191958, 1.71, 14008248.18),
#  ('Sierra Leone', 5879098, 2.35, 13815880.3),
#  ('Germany', 80854408, 0.17, 13745249.360000001),
#  ('Korea, North', 24983205, 0.53, 13241098.65),
#  ('Dominican Republic', 10478756, 1.23, 12888869.879999999),
#  ('Israel', 8049314, 1.56, 12556929.84),
#  ('Papua New Guinea', 6672429, 1.78, 11876923.620000001),
#  ('Haiti', 10110019, 1.17, 11828722.229999999),
#  ('Central African Republic', 5391539, 2.13, 11483978.07),
#  ('Singapore', 5674472, 1.89, 10724752.08),
#  ('Laos', 6911544, 1.55, 10712893.200000001),
#  ('Liberia', 4195666, 2.47, 10363295.020000001),
#  ('Tunisia', 11037225, 0.89, 9823130.25),
#  ('Congo, Republic of the', 4755097, 2.0, 9510194.0),
#  ('Azerbaijan', 9780780, 0.96, 9389548.799999999),
#  ('Belgium', 11323973, 0.76, 8606219.48),
#  ('Mauritania', 3596702, 2.23, 8020645.46),
#  ('Paraguay', 6783272, 1.16, 7868595.52),
#  ('Sweden', 9801616, 0.8, 7841292.800000001),
#  ('Netherlands', 16947904, 0.41, 6948640.64),
#  ('Korea, South', 49115196, 0.14, 6876127.44),
#  ('Oman', 3286936, 2.07, 6803957.52),
#  ('Qatar', 2194817, 3.07, 6738088.1899999995),
#  ('Jordan', 8117564, 0.83, 6737578.12),
#  ('Romania', 21666350, 0.3, 6499905.0),
#  ('Kyrgyzstan', 5664939, 1.11, 6288082.290000001),
#  ('Ireland', 4892305, 1.25, 6115381.25),
#  ('Turkmenistan', 5231422, 1.14, 5963821.079999999),
#  ('Nicaragua', 5907881, 1.0, 5907881.0),
#  ('Norway', 5207689, 1.13, 5884688.569999999),
#  ('Costa Rica', 4814144, 1.22, 5873255.68),
#  ('Switzerland', 8121830, 0.71, 5766499.3),
#  ('Russia', 142423773, 0.04, 5696950.92),
#  ('West Bank', 2785366, 1.95, 5431463.7),
#  ('Taiwan', 23415126, 0.23, 5385478.98),
#  ('Lebanon', 6184701, 0.86, 5318842.86),
#  ('Gaza Strip', 1869055, 2.81, 5252044.55),
#  ('Panama', 3657024, 1.32, 4827271.680000001),
#  ('Austria', 8665550, 0.55, 4766052.5),
#  ('Kuwait', 2788534, 1.62, 4517425.08),
#  ('Gambia, The', 1967709, 2.16, 4250251.44),
#  ('Bulgaria', 7186893, 0.58, 4168397.94),
#  ('Mongolia', 2992908, 1.31, 3920709.48),
#  ('Moldova', 3546847, 1.03, 3653252.41),
#  ('New Zealand', 4438393, 0.82, 3639482.26),
#  ('Poland', 38562189, 0.09, 3470597.01),
#  ('Serbia', 7176794, 0.46, 3301325.24),
#  ('Guinea-Bissau', 1726170, 1.91, 3296984.6999999997),
#  ('Gabon', 1705336, 1.93, 3291298.48),
#  ('Bahrain', 1346613, 2.41, 3245337.33),
#  ('Lithuania', 2884433, 1.04, 2999810.3200000003),
#  ('Timor-Leste', 1231116, 2.42, 2979300.7199999997),
#  ('Syria', 17064854, 0.16, 2730376.64),
#  ('Hong Kong', 7141106, 0.38, 2713620.2800000003),
#  ('Botswana', 2182719, 1.21, 2641089.9899999998),
#  ('Finland', 5476922, 0.4, 2190768.8000000003),
#  ('Hungary', 9897541, 0.22, 2177459.02),
#  ('Puerto Rico', 3598357, 0.6, 2159014.1999999997),
#  ('Latvia', 1986705, 1.06, 2105907.3000000003),
#  ('Jamaica', 2950210, 0.68, 2006142.8),
#  ('Belarus', 9589689, 0.2, 1917937.8),
#  ('Equatorial Guinea', 740743, 2.51, 1859264.93),
#  ('Djibouti', 828324, 2.2, 1822312.8),
#  ('Czech Republic', 10644842, 0.16, 1703174.72),
#  ('Cyprus', 1189197, 1.43, 1700551.71),
#  ('Cuba', 11031433, 0.15, 1654714.95),
#  ('Western Sahara', 570866, 2.82, 1609842.1199999999),
#  ('Swaziland', 1435613, 1.11, 1593530.4300000002),
#  ('El Salvador', 6141350, 0.25, 1535337.5),
#  ('Comoros', 780971, 1.77, 1382318.67),
#  ('Namibia', 2212307, 0.59, 1305261.13),
#  ('Solomon Islands', 622469, 2.02, 1257387.3800000001),
#  ('Denmark', 5581503, 0.22, 1227930.66),
#  ('Luxembourg', 570252, 2.13, 1214636.76),
#  ('Portugal', 10825309, 0.09, 974277.8099999999),
#  ('Albania', 3029278, 0.3, 908783.4),
#  ('Uruguay', 3341893, 0.27, 902311.1100000001),
#  ('Mauritius', 1339827, 0.64, 857489.28),
#  ('Bhutan', 741919, 1.11, 823530.0900000001),
#  ('Cabo Verde', 545993, 1.36, 742550.4800000001),
#  ('Brunei', 429646, 1.62, 696026.52),
#  ('Estonia', 1265420, 0.55, 695981.0),
#  ('Belize', 347369, 1.87, 649580.03),
#  ('Suriname', 579633, 1.08, 626003.64),
#  ('Lesotho', 1947701, 0.32, 623264.3200000001),
#  ('Fiji', 909389, 0.67, 609290.63),
#  ('Croatia', 4464844, 0.13, 580429.72),
#  ('Vanuatu', 272264, 1.95, 530914.7999999999),
#  ('Slovenia', 1983412, 0.26, 515687.12),
#  ('Bosnia and Herzegovina', 3867055, 0.13, 502717.15),
#  ('Macau', 592731, 0.8, 474184.80000000005),
#  ('Armenia', 3056382, 0.15, 458457.3),
#  ('Macedonia', 2096015, 0.2, 419203.0),
#  ('Iceland', 331918, 1.21, 401620.77999999997),
#  ('Georgia', 4931226, 0.08, 394498.08),
#  ('New Caledonia', 271615, 1.38, 374828.69999999995),
#  ('Sao Tome and Principe', 194006, 1.84, 356971.04000000004),
#  ('Bahamas, The', 324597, 0.85, 275907.45),
#  ('Montenegro', 647073, 0.42, 271770.66),
#  ('French Polynesia', 282703, 0.94, 265740.82),
#  ('Trinidad and Tobago', 1222363, 0.13, 158907.19),
#  ('Aruba', 112162, 1.33, 149175.46000000002),
#  ('Malta', 413965, 0.31, 128329.15),
#  ('Kiribati', 105711, 1.15, 121567.65),
#  ('Marshall Islands', 72191, 1.66, 119837.06),
#  ('Cayman Islands', 56092, 2.1, 117793.20000000001),
#  ('Turks and Caicos Islands', 50280, 2.3, 115643.99999999999),
#  ('Samoa', 197773, 0.58, 114708.34),
#  ('Antigua and Barbuda', 92436, 1.24, 114620.64),
#  ('Northern Mariana Islands', 52344, 2.18, 114109.92000000001),
#  ('Slovakia', 5445027, 0.02, 108900.54000000001),
#  ('Greece', 10775643, 0.01, 107756.43000000001),
#  ('Barbados', 290604, 0.31, 90087.24),
#  ('Guam', 161785, 0.54, 87363.90000000001),
#  ('Jersey', 97294, 0.8, 77835.2),
#  ('British Virgin Islands', 33454, 2.32, 77613.28),
#  ('Seychelles', 92430, 0.83, 76716.9),
#  ('Isle of Man', 87545, 0.76, 66534.2),
#  ('Curacao', 148406, 0.43, 63814.58),
#  ('Virgin Islands', 103574, 0.59, 61108.659999999996),
#  ('Sint Maarten', 39689, 1.51, 59930.39),
#  ('Saint Lucia', 163922, 0.34, 55733.48),
#  ('Grenada', 110694, 0.48, 53133.119999999995),
#  ('Micronesia, Federated States of', 105216, 0.46, 48399.36),
#  ('Saint Kitts and Nevis', 51936, 0.76, 39471.36),
#  ('Bermuda', 70196, 0.5, 35098.0),
#  ('Anguilla', 16418, 2.03, 33328.53999999999),
#  ('Liechtenstein', 37624, 0.84, 31604.16),
#  ('Maldives', 393253, 0.08, 31460.24),
#  ('Cook Islands', 9838, 2.95, 29022.100000000002),
#  ('Saint Vincent and the Grenadines', 102627, 0.28, 28735.56),
#  ('San Marino', 33020, 0.82, 27076.399999999998),
#  ('Faroe Islands', 50196, 0.51, 25599.96),
#  ('Guernsey', 66080, 0.34, 22467.2),
#  ('American Samoa', 54343, 0.3, 16302.9),
#  ('Dominica', 73607, 0.21, 15457.47),
#  ('Guyana', 735222, 0.02, 14704.44),
#  ('Andorra', 85580, 0.12, 10269.6),
#  ('Tuvalu', 10869, 0.82, 8912.58),
#  ('Palau', 21265, 0.38, 8080.7),
#  ('Gibraltar', 29258, 0.24, 7021.92),
#  ('Saint Pierre and Miquelon', 5657, 1.08, 6109.56),
#  ('Nauru', 9540, 0.55, 5247.0),
#  ('Wallis and Futuna', 15613, 0.33, 5152.29),
#  ('Monaco', 30535, 0.12, 3664.2),
#  ('Tonga', 106501, 0.03, 3195.0299999999997),
#  ('Montserrat', 5241, 0.5, 2620.5),
#  ('Saint Helena, Ascension, and Tristan da Cunha', 7795, 0.24, 1870.8),
#  ('Christmas Island', 1530, 1.11, 1698.3000000000002),
#  ('Svalbard', 1872, 0.03, 56.16),
#  ('Niue', 1190, 0.03, 35.699999999999996),
#  ('Falkland Islands (Islas Malvinas)', 3361, 0.01, 33.61),
#  ('Norfolk Island', 2210, 0.01, 22.1),
#  ('Tokelau', 1337, 0.01, 13.370000000000001),
#  ('Holy See (Vatican City)', 842, 0.0, 0.0),
#  ('Cocos (Keeling) Islands', 596, 0.0, 0.0),
#  ('Greenland', 57733, 0.0, 0.0),
#  ('Pitcairn Islands', 48, 0.0, 0.0),
#  ('Kosovo', 1870981, None, None),
#  ('Ashmore and Cartier Islands', None, None, None),
#  ('Coral Sea Islands', None, None, None),
#  ('Heard Island and McDonald Islands', None, None, None),
#  ('Clipperton Island', None, None, None),
#  ('French Southern and Antarctic Lands', None, None, None),
#  ('Saint Barthelemy', 7237, None, None),
#  ('Saint Martin', 31754, None, None),
#  ('Bouvet Island', None, None, None),
#  ('Jan Mayen', None, None, None),
#  ('Akrotiri', 15700, None, None),
#  ('British Indian Ocean Territory', None, None, None),
#  ('Dhekelia', 15700, None, None),
#  ('South Georgia and South Sandwich Islands', None, None, None),
#  ('Navassa Island', None, None, None),
#  ('Wake Island', None, None, None),
#  ('United States Pacific Island Wildlife Refuges', None, None, None),
#  ('Antarctica', 0, None, None),
#  ('Paracel Islands', None, None, None),
#  ('Spratly Islands', None, None, None),
#  ('Arctic Ocean', None, None, None),
#  ('Atlantic Ocean', None, None, None),
#  ('Indian Ocean', None, None, None),
#  ('Pacific Ocean', None, None, None),
#  ('Southern Ocean', None, None, None)]

# %% [markdown]
# If multiply the current year of population with population growth in the same year "India" will be the country in the next year that is the most population in the world.

# %% [markdown]
# ## Exploring which country have a higher death rate than birth rate

# %%
# %%sql
# SELECT name, birth_rate, death_rate,
#        ROUND(death_rate - birth_rate, 2) AS diff
#   FROM facts
#  WHERE name <> 'World'
#    AND birth_rate < death_rate
#  ORDER BY diff DESC;
# Out:
# Done.
# [('Bulgaria', 8.92, 14.44, 5.52),
#  ('Serbia', 9.08, 13.66, 4.58),
#  ('Latvia', 10.0, 14.31, 4.31),
#  ('Lithuania', 10.1, 14.27, 4.17),
#  ('Ukraine', 10.72, 14.46, 3.74),
#  ('Hungary', 9.16, 12.73, 3.57),
#  ('Germany', 8.47, 11.42, 2.95),
#  ('Slovenia', 8.42, 11.37, 2.95),
#  ('Romania', 9.14, 11.9, 2.76),
#  ('Croatia', 9.45, 12.18, 2.73),
#  ('Belarus', 10.7, 13.36, 2.66),
#  ('Monaco', 6.65, 9.24, 2.59),
#  ('Greece', 8.66, 11.09, 2.43),
#  ('Saint Pierre and Miquelon', 7.42, 9.72, 2.3),
#  ('Russia', 11.6, 13.69, 2.09),
#  ('Estonia', 10.51, 12.4, 1.89),
#  ('Portugal', 9.27, 11.02, 1.75),
#  ('Japan', 7.93, 9.51, 1.58),
#  ('Italy', 8.74, 10.19, 1.45),
#  ('Bosnia and Herzegovina', 8.87, 9.75, 0.88),
#  ('Czech Republic', 9.63, 10.34, 0.71),
#  ('Moldova', 12.0, 12.59, 0.59),
#  ('Poland', 9.74, 10.19, 0.45),
#  ('Austria', 9.41, 9.42, 0.01)]

# %% [markdown]
# Another topic that is which countries that have a higher death rate than birth rate!!
#
# For the answer is "Bulgaria"

# %% [markdown]
# ## Exploring about water area and land area
# 1) which countries have the highest ratios of water to land?
#
# 2) which countries have more water than land?
#
# Let's explore the data..

# %%
# %%sql
# SELECT name, area_water
#   FROM facts
#  WHERE name <> 'World'
#  ORDER BY area_water DESC;
# Out:
# Done.
# [('Canada', 891163),
#  ('Russia', 720500),
#  ('United States', 664709),
#  ('India', 314070),
#  ('China', 270550),
#  ('Brazil', 157630),
#  ('Iran', 116600),
#  ('Ethiopia', 104300),
#  ('Colombia', 100210),
#  ('Indonesia', 93000),
#  ('Congo, Democratic Republic of the', 77810),
#  ('Tanzania', 61500),
#  ('Australia', 58920),
#  ('British Indian Ocean Territory', 54340),
#  ('Uganda', 43938),
#  ('Argentina', 43710),
#  ('Sweden', 39960),
#  ('Finland', 34330),
#  ('Venezuela', 30000),
#  ('Pakistan', 25220),
#  ('Kazakhstan', 25200),
#  ('Chad', 24800),
#  ('Malawi', 24404),
#  ('Ukraine', 24220),
#  ('Burma', 23070),
#  ('Uzbekistan', 22000),
#  ('Vietnam', 21140),
#  ('Mexico', 20430),
#  ('Mali', 20002),
#  ('Norway', 19520),
#  ('Bangladesh', 18290),
#  ('Turkmenistan', 18170),
#  ('Guyana', 18120),
#  ('Eritrea', 16600),
#  ('Bolivia', 15280),
#  ('Liberia', 15049),
#  ('Botswana', 15000),
#  ('Turkey', 13930),
#  ('Japan', 13430),
#  ('Mozambique', 13000),
#  ('Nigeria', 13000),
#  ('Chile', 12290),
#  ('Kenya', 11227),
#  ('Ghana', 11000),
#  ('Mongolia', 10560),
#  ('Nicaragua', 10380),
#  ('Somalia', 10320),
#  ('Gabon', 10000),
#  ('Papua New Guinea', 9980),
#  ('Paraguay', 9450),
#  ('Zambia', 9220),
#  ('Romania', 8500),
#  ('Poland', 8430),
#  ('Germany', 8350),
#  ('Tunisia', 8250),
#  ('Kyrgyzstan', 8150),
#  ('Guinea-Bissau', 8005),
#  ('Suriname', 7820),
#  ('Netherlands', 7650),
#  ('Italy', 7200),
#  ('Ecuador', 6720),
#  ('Spain', 6390),
#  ('Egypt', 6000),
#  ('Laos', 6000),
#  ('Madagascar', 5501),
#  ('Peru', 5220),
#  ('Puerto Rico', 4921),
#  ('Belarus', 4700),
#  ('South Africa', 4620),
#  ('Cambodia', 4520),
#  ("Cote d'Ivoire", 4460),
#  ('Senegal', 4192),
#  ('Azerbaijan', 3971),
#  ('Zimbabwe', 3910),
#  ('Bahamas, The', 3870),
#  ('Nepal', 3830),
#  ('Taiwan', 3720),
#  ('Hungary', 3420),
#  ('France', 3374),
#  ('Estonia', 2840),
#  ('Korea, South', 2800),
#  ('Iceland', 2750),
#  ('Cameroon', 2730),
#  ('Lithuania', 2620),
#  ('Tajikistan', 2590),
#  ('Togo', 2400),
#  ('Bulgaria', 2390),
#  ('Latvia', 2340),
#  ('Thailand', 2230),
#  ('Burundi', 2150),
#  ('Benin', 2000),
#  ('Philippines', 1830),
#  ('Guatemala', 1730),
#  ('United Kingdom', 1680),
#  ('Rwanda', 1670),
#  ('Czech Republic', 1620),
#  ('Virgin Islands', 1564),
#  ('Syria', 1550),
#  ('Armenia', 1540),
#  ('Austria', 1426),
#  ('Ireland', 1390),
#  ('Albania', 1350),
#  ('Greece', 1310),
#  ('Switzerland', 1280),
#  ('Uruguay', 1200),
#  ('Malaysia', 1190),
#  ('Gambia, The', 1180),
#  ('Panama', 1080),
#  ('Cuba', 1040),
#  ('Namibia', 1002),
#  ('Sri Lanka', 980),
#  ('Moldova', 960),
#  ('Iraq', 950),
#  ('Slovakia', 930),
#  ('Solomon Islands', 910),
#  ('Denmark', 660),
#  ('Croatia', 620),
#  ('Portugal', 620),
#  ('Jordan', 540),
#  ('Brunei', 500),
#  ('Congo, Republic of the', 500),
#  ('Israel', 440),
#  ('Burkina Faso', 400),
#  ('Montenegro', 360),
#  ('Dominican Republic', 350),
#  ('French Polynesia', 340),
#  ('El Salvador', 320),
#  ('Niger', 300),
#  ('New Caledonia', 300),
#  ('Macedonia', 280),
#  ('Belgium', 250),
#  ('Morocco', 250),
#  ('West Bank', 220),
#  ('Honduras', 200),
#  ('Haiti', 190),
#  ('Lebanon', 170),
#  ('Belize', 160),
#  ('Jamaica', 160),
#  ('Swaziland', 160),
#  ('Guinea', 140),
#  ('Korea, North', 130),
#  ('Slovenia', 122),
#  ('Sierra Leone', 120),
#  ('Costa Rica', 40),
#  ('Hong Kong', 35),
#  ('Tonga', 30),
#  ('Djibouti', 20),
#  ('Bosnia and Herzegovina', 10),
#  ('Cyprus', 10),
#  ('Mauritius', 10),
#  ('Saint Lucia', 10),
#  ('Samoa', 10),
#  ('Singapore', 10),
#  ('Afghanistan', 0),
#  ('Algeria', 0),
#  ('Andorra', 0),
#  ('Angola', 0),
#  ('Antigua and Barbuda', 0),
#  ('Bahrain', 0),
#  ('Barbados', 0),
#  ('Bhutan', 0),
#  ('Cabo Verde', 0),
#  ('Central African Republic', 0),
#  ('Comoros', 0),
#  ('Dominica', 0),
#  ('Equatorial Guinea', 0),
#  ('Fiji', 0),
#  ('Georgia', 0),
#  ('Grenada', 0),
#  ('Kiribati', 0),
#  ('Kosovo', 0),
#  ('Kuwait', 0),
#  ('Lesotho', 0),
#  ('Libya', 0),
#  ('Liechtenstein', 0),
#  ('Luxembourg', 0),
#  ('Maldives', 0),
#  ('Malta', 0),
#  ('Marshall Islands', 0),
#  ('Mauritania', 0),
#  ('Micronesia, Federated States of', 0),
#  ('Monaco', 0),
#  ('Nauru', 0),
#  ('Oman', 0),
#  ('Palau', 0),
#  ('Qatar', 0),
#  ('Saint Kitts and Nevis', 0),
#  ('Saint Vincent and the Grenadines', 0),
#  ('San Marino', 0),
#  ('Sao Tome and Principe', 0),
#  ('Saudi Arabia', 0),
#  ('Serbia', 0),
#  ('Seychelles', 0),
#  ('Timor-Leste', 0),
#  ('Trinidad and Tobago', 0),
#  ('Tuvalu', 0),
#  ('United Arab Emirates', 0),
#  ('Vanuatu', 0),
#  ('Holy See (Vatican City)', 0),
#  ('Yemen', 0),
#  ('Ashmore and Cartier Islands', 0),
#  ('Christmas Island', 0),
#  ('Cocos (Keeling) Islands', 0),
#  ('Coral Sea Islands', 0),
#  ('Heard Island and McDonald Islands', 0),
#  ('Norfolk Island', 0),
#  ('Macau', 0),
#  ('Faroe Islands', 0),
#  ('Clipperton Island', 0),
#  ('Saint Pierre and Miquelon', 0),
#  ('Wallis and Futuna', 0),
#  ('Aruba', 0),
#  ('Curacao', 0),
#  ('Sint Maarten', 0),
#  ('Cook Islands', 0),
#  ('Niue', 0),
#  ('Tokelau', 0),
#  ('Bouvet Island', 0),
#  ('Jan Mayen', 0),
#  ('Svalbard', 0),
#  ('Anguilla', 0),
#  ('Bermuda', 0),
#  ('British Virgin Islands', 0),
#  ('Cayman Islands', 0),
#  ('Falkland Islands (Islas Malvinas)', 0),
#  ('Gibraltar', 0),
#  ('Guernsey', 0),
#  ('Jersey', 0),
#  ('Isle of Man', 0),
#  ('Montserrat', 0),
#  ('Pitcairn Islands', 0),
#  ('Saint Helena, Ascension, and Tristan da Cunha', 0),
#  ('South Georgia and South Sandwich Islands', 0),
#  ('Turks and Caicos Islands', 0),
#  ('American Samoa', 0),
#  ('Guam', 0),
#  ('Navassa Island', 0),
#  ('Northern Mariana Islands', 0),
#  ('Wake Island', 0),
#  ('Gaza Strip', 0),
#  ('Paracel Islands', 0),
#  ('Spratly Islands', 0),
#  ('Western Sahara', 0),
#  ('New Zealand', None),
#  ('South Sudan', None),
#  ('Sudan', None),
#  ('European Union', None),
#  ('Greenland', None),
#  ('French Southern and Antarctic Lands', None),
#  ('Saint Barthelemy', None),
#  ('Saint Martin', None),
#  ('Akrotiri', None),
#  ('Dhekelia', None),
#  ('United States Pacific Island Wildlife Refuges', None),
#  ('Antarctica', None),
#  ('Arctic Ocean', None),
#  ('Atlantic Ocean', None),
#  ('Indian Ocean', None),
#  ('Pacific Ocean', None),
#  ('Southern Ocean', None)]

# %%
# %%sql
# SELECT MIN(area_water),
#        MAX(area_water)
#   FROM facts
#  WHERE name <> 'World'
# Out:
# Done.
# [(0, 891163)]

# %% [markdown]
# There's some countries with area water with 0.
#
# Let's explore more to find insight.

# %%
# %%sql
# SELECT name, area_water
#   FROM facts
#  WHERE area_water = (SELECT MIN(area_water)
#                        FROM facts
#                       WHERE name <> 'World');
# Out:
# Done.
# [('Afghanistan', 0),
#  ('Algeria', 0),
#  ('Andorra', 0),
#  ('Angola', 0),
#  ('Antigua and Barbuda', 0),
#  ('Bahrain', 0),
#  ('Barbados', 0),
#  ('Bhutan', 0),
#  ('Cabo Verde', 0),
#  ('Central African Republic', 0),
#  ('Comoros', 0),
#  ('Dominica', 0),
#  ('Equatorial Guinea', 0),
#  ('Fiji', 0),
#  ('Georgia', 0),
#  ('Grenada', 0),
#  ('Kiribati', 0),
#  ('Kosovo', 0),
#  ('Kuwait', 0),
#  ('Lesotho', 0),
#  ('Libya', 0),
#  ('Liechtenstein', 0),
#  ('Luxembourg', 0),
#  ('Maldives', 0),
#  ('Malta', 0),
#  ('Marshall Islands', 0),
#  ('Mauritania', 0),
#  ('Micronesia, Federated States of', 0),
#  ('Monaco', 0),
#  ('Nauru', 0),
#  ('Oman', 0),
#  ('Palau', 0),
#  ('Qatar', 0),
#  ('Saint Kitts and Nevis', 0),
#  ('Saint Vincent and the Grenadines', 0),
#  ('San Marino', 0),
#  ('Sao Tome and Principe', 0),
#  ('Saudi Arabia', 0),
#  ('Serbia', 0),
#  ('Seychelles', 0),
#  ('Timor-Leste', 0),
#  ('Trinidad and Tobago', 0),
#  ('Tuvalu', 0),
#  ('United Arab Emirates', 0),
#  ('Vanuatu', 0),
#  ('Holy See (Vatican City)', 0),
#  ('Yemen', 0),
#  ('Ashmore and Cartier Islands', 0),
#  ('Christmas Island', 0),
#  ('Cocos (Keeling) Islands', 0),
#  ('Coral Sea Islands', 0),
#  ('Heard Island and McDonald Islands', 0),
#  ('Norfolk Island', 0),
#  ('Macau', 0),
#  ('Faroe Islands', 0),
#  ('Clipperton Island', 0),
#  ('Saint Pierre and Miquelon', 0),
#  ('Wallis and Futuna', 0),
#  ('Aruba', 0),
#  ('Curacao', 0),
#  ('Sint Maarten', 0),
#  ('Cook Islands', 0),
#  ('Niue', 0),
#  ('Tokelau', 0),
#  ('Bouvet Island', 0),
#  ('Jan Mayen', 0),
#  ('Svalbard', 0),
#  ('Anguilla', 0),
#  ('Bermuda', 0),
#  ('British Virgin Islands', 0),
#  ('Cayman Islands', 0),
#  ('Falkland Islands (Islas Malvinas)', 0),
#  ('Gibraltar', 0),
#  ('Guernsey', 0),
#  ('Jersey', 0),
#  ('Isle of Man', 0),
#  ('Montserrat', 0),
#  ('Pitcairn Islands', 0),
#  ('Saint Helena, Ascension, and Tristan da Cunha', 0),
#  ('South Georgia and South Sandwich Islands', 0),
#  ('Turks and Caicos Islands', 0),
#  ('American Samoa', 0),
#  ('Guam', 0),
#  ('Navassa Island', 0),
#  ('Northern Mariana Islands', 0),
#  ('Wake Island', 0),
#  ('Gaza Strip', 0),
#  ('Paracel Islands', 0),
#  ('Spratly Islands', 0),
#  ('Western Sahara', 0)]

# %%
# %%sql
# SELECT COUNT(*) AS no_water_area
#   FROM facts
#  WHERE area_water = (SELECT MIN(area_water)
#                        FROM facts
#                       WHERE name <> 'World');
# Out:
# Done.
# [(90,)]

# %% [markdown]
# There are 90 countries that don't have area water in thier countries.

# %%
# %%sql
# SELECT name, area_land
#   FROM facts
#  WHERE name <> 'World'
#  ORDER BY area_land DESC;
# Out:
# Done.
# [('Russia', 16377742),
#  ('China', 9326410),
#  ('United States', 9161966),
#  ('Canada', 9093507),
#  ('Brazil', 8358140),
#  ('Australia', 7682300),
#  ('India', 2973193),
#  ('Argentina', 2736690),
#  ('Kazakhstan', 2699700),
#  ('Algeria', 2381741),
#  ('Congo, Democratic Republic of the', 2267048),
#  ('Greenland', 2166086),
#  ('Saudi Arabia', 2149690),
#  ('Mexico', 1943945),
#  ('Indonesia', 1811569),
#  ('Libya', 1759540),
#  ('Mongolia', 1553556),
#  ('Iran', 1531595),
#  ('Peru', 1279996),
#  ('Niger', 1266700),
#  ('Chad', 1259200),
#  ('Angola', 1246700),
#  ('Mali', 1220190),
#  ('South Africa', 1214470),
#  ('Bolivia', 1083301),
#  ('Colombia', 1038700),
#  ('Mauritania', 1030700),
#  ('Egypt', 995450),
#  ('Nigeria', 910768),
#  ('Tanzania', 885800),
#  ('Venezuela', 882050),
#  ('Namibia', 823290),
#  ('Mozambique', 786380),
#  ('Pakistan', 770875),
#  ('Turkey', 769632),
#  ('Chile', 743812),
#  ('Zambia', 743398),
#  ('Burma', 653508),
#  ('Afghanistan', 652230),
#  ('France', 640427),
#  ('Somalia', 627337),
#  ('Central African Republic', 622984),
#  ('Madagascar', 581540),
#  ('Ukraine', 579330),
#  ('Kenya', 569140),
#  ('Botswana', 566730),
#  ('Yemen', 527968),
#  ('Thailand', 510890),
#  ('Spain', 498980),
#  ('Cameroon', 472710),
#  ('Turkmenistan', 469930),
#  ('Papua New Guinea', 452860),
#  ('Morocco', 446300),
#  ('Iraq', 437367),
#  ('Uzbekistan', 425400),
#  ('Sweden', 410335),
#  ('Paraguay', 397302),
#  ('Zimbabwe', 386847),
#  ('Japan', 364485),
#  ('Germany', 348672),
#  ('Congo, Republic of the', 341500),
#  ('Malaysia', 328657),
#  ("Cote d'Ivoire", 318003),
#  ('Vietnam', 310070),
#  ('Oman', 309500),
#  ('Norway', 304282),
#  ('Poland', 304255),
#  ('Finland', 303815),
#  ('Philippines', 298170),
#  ('Italy', 294140),
#  ('Antarctica', 280000),
#  ('Ecuador', 276841),
#  ('Burkina Faso', 273800),
#  ('New Zealand', 267710),
#  ('Western Sahara', 266000),
#  ('Gabon', 257667),
#  ('Guinea', 245717),
#  ('United Kingdom', 241930),
#  ('Laos', 230800),
#  ('Romania', 229891),
#  ('Ghana', 227533),
#  ('Belarus', 202900),
#  ('Uganda', 197100),
#  ('Guyana', 196849),
#  ('Senegal', 192530),
#  ('Kyrgyzstan', 191801),
#  ('Syria', 183630),
#  ('Cambodia', 176515),
#  ('Uruguay', 175015),
#  ('Suriname', 156000),
#  ('Tunisia', 155360),
#  ('Nepal', 143351),
#  ('Tajikistan', 141510),
#  ('Greece', 130647),
#  ('Bangladesh', 130170),
#  ('Korea, North', 120408),
#  ('Nicaragua', 119990),
#  ('Honduras', 111890),
#  ('Benin', 110622),
#  ('Cuba', 109820),
#  ('Bulgaria', 108489),
#  ('Guatemala', 107159),
#  ('Eritrea', 101000),
#  ('Iceland', 100250),
#  ('Korea, South', 96920),
#  ('Liberia', 96320),
#  ('Malawi', 94080),
#  ('Portugal', 91470),
#  ('Hungary', 89608),
#  ('Jordan', 88802),
#  ('United Arab Emirates', 83600),
#  ('Azerbaijan', 82629),
#  ('Austria', 82445),
#  ('Serbia', 77474),
#  ('Czech Republic', 77247),
#  ('Panama', 74340),
#  ('Sierra Leone', 71620),
#  ('Georgia', 69700),
#  ('Ireland', 68883),
#  ('Sri Lanka', 64630),
#  ('Lithuania', 62680),
#  ('Latvia', 62249),
#  ('Svalbard', 62045),
#  ('Croatia', 55974),
#  ('Togo', 54385),
#  ('Bosnia and Herzegovina', 51187),
#  ('Costa Rica', 51060),
#  ('Dominican Republic', 48320),
#  ('Slovakia', 48105),
#  ('Denmark', 42434),
#  ('Estonia', 42388),
#  ('Switzerland', 39997),
#  ('Bhutan', 38394),
#  ('Netherlands', 33893),
#  ('Moldova', 32891),
#  ('Taiwan', 32260),
#  ('Lesotho', 30355),
#  ('Belgium', 30278),
#  ('Armenia', 28203),
#  ('Guinea-Bissau', 28120),
#  ('Equatorial Guinea', 28051),
#  ('Solomon Islands', 27986),
#  ('Haiti', 27560),
#  ('Albania', 27398),
#  ('Burundi', 25680),
#  ('Macedonia', 25433),
#  ('Rwanda', 24668),
#  ('Djibouti', 23180),
#  ('Belize', 22806),
#  ('El Salvador', 20721),
#  ('Israel', 20330),
#  ('Slovenia', 20151),
#  ('New Caledonia', 18275),
#  ('Fiji', 18274),
#  ('Kuwait', 17818),
#  ('Swaziland', 17204),
#  ('Timor-Leste', 14874),
#  ('Montenegro', 13452),
#  ('Vanuatu', 12189),
#  ('Falkland Islands (Islas Malvinas)', 12173),
#  ('Qatar', 11586),
#  ('Kosovo', 10887),
#  ('Jamaica', 10831),
#  ('Lebanon', 10230),
#  ('Gambia, The', 10120),
#  ('Bahamas, The', 10010),
#  ('Cyprus', 9241),
#  ('Puerto Rico', 8870),
#  ('West Bank', 5640),
#  ('Brunei', 5265),
#  ('Trinidad and Tobago', 5128),
#  ('Cabo Verde', 4033),
#  ('South Georgia and South Sandwich Islands', 3903),
#  ('French Polynesia', 3827),
#  ('Samoa', 2821),
#  ('Luxembourg', 2586),
#  ('Comoros', 2235),
#  ('Mauritius', 2030),
#  ('Faroe Islands', 1393),
#  ('Hong Kong', 1073),
#  ('Sao Tome and Principe', 964),
#  ('Turks and Caicos Islands', 948),
#  ('Kiribati', 811),
#  ('Bahrain', 760),
#  ('Dominica', 751),
#  ('Tonga', 717),
#  ('Micronesia, Federated States of', 702),
#  ('Singapore', 687),
#  ('Saint Lucia', 606),
#  ('Isle of Man', 572),
#  ('Guam', 544),
#  ('Andorra', 468),
#  ('Northern Mariana Islands', 464),
#  ('Palau', 459),
#  ('Seychelles', 455),
#  ('Curacao', 444),
#  ('Antigua and Barbuda', 442),
#  ('Barbados', 430),
#  ('Heard Island and McDonald Islands', 412),
#  ('Saint Vincent and the Grenadines', 389),
#  ('Jan Mayen', 377),
#  ('Gaza Strip', 360),
#  ('Virgin Islands', 346),
#  ('Grenada', 344),
#  ('Malta', 316),
#  ('Maldives', 298),
#  ('Cayman Islands', 264),
#  ('Saint Kitts and Nevis', 261),
#  ('Niue', 260),
#  ('Saint Pierre and Miquelon', 242),
#  ('Cook Islands', 236),
#  ('American Samoa', 199),
#  ('Marshall Islands', 181),
#  ('Aruba', 180),
#  ('Liechtenstein', 160),
#  ('British Virgin Islands', 151),
#  ('Wallis and Futuna', 142),
#  ('Christmas Island', 135),
#  ('Saint Helena, Ascension, and Tristan da Cunha', 122),
#  ('Jersey', 116),
#  ('Montserrat', 102),
#  ('Anguilla', 91),
#  ('Guernsey', 78),
#  ('San Marino', 61),
#  ('British Indian Ocean Territory', 60),
#  ('Saint Martin', 54),
#  ('Bermuda', 54),
#  ('Bouvet Island', 49),
#  ('Pitcairn Islands', 47),
#  ('Norfolk Island', 36),
#  ('Sint Maarten', 34),
#  ('Macau', 28),
#  ('Tuvalu', 26),
#  ('Nauru', 21),
#  ('Cocos (Keeling) Islands', 14),
#  ('Tokelau', 12),
#  ('Paracel Islands', 7),
#  ('Clipperton Island', 6),
#  ('Gibraltar', 6),
#  ('Wake Island', 6),
#  ('Ashmore and Cartier Islands', 5),
#  ('Navassa Island', 5),
#  ('Spratly Islands', 5),
#  ('Coral Sea Islands', 3),
#  ('Monaco', 2),
#  ('Holy See (Vatican City)', 0),
#  ('Ethiopia', None),
#  ('South Sudan', None),
#  ('Sudan', None),
#  ('European Union', None),
#  ('French Southern and Antarctic Lands', None),
#  ('Saint Barthelemy', None),
#  ('Akrotiri', None),
#  ('Dhekelia', None),
#  ('United States Pacific Island Wildlife Refuges', None),
#  ('Arctic Ocean', None),
#  ('Atlantic Ocean', None),
#  ('Indian Ocean', None),
#  ('Pacific Ocean', None),
#  ('Southern Ocean', None)]

# %% [markdown]
# ### Conclude
#
#  - For the country that have the most area of land is "Russia".
#  - For the country that have the most area of water is "Canada".
#
# Let's find out which countries that have area of water than land

# %%
# %%sql
# SELECT name,
#        area_water - area_land AS diff_area
#   FROM facts
#  WHERE name <> 'World'
#  ORDER BY diff_area DESC;
# Out:
# Done.
# [('British Indian Ocean Territory', 54280),
#  ('Virgin Islands', 1218),
#  ('Holy See (Vatican City)', 0),
#  ('Monaco', -2),
#  ('Coral Sea Islands', -3),
#  ('Ashmore and Cartier Islands', -5),
#  ('Navassa Island', -5),
#  ('Spratly Islands', -5),
#  ('Clipperton Island', -6),
#  ('Gibraltar', -6),
#  ('Wake Island', -6),
#  ('Paracel Islands', -7),
#  ('Tokelau', -12),
#  ('Cocos (Keeling) Islands', -14),
#  ('Nauru', -21),
#  ('Tuvalu', -26),
#  ('Macau', -28),
#  ('Sint Maarten', -34),
#  ('Norfolk Island', -36),
#  ('Pitcairn Islands', -47),
#  ('Bouvet Island', -49),
#  ('Bermuda', -54),
#  ('San Marino', -61),
#  ('Guernsey', -78),
#  ('Anguilla', -91),
#  ('Montserrat', -102),
#  ('Jersey', -116),
#  ('Saint Helena, Ascension, and Tristan da Cunha', -122),
#  ('Christmas Island', -135),
#  ('Wallis and Futuna', -142),
#  ('British Virgin Islands', -151),
#  ('Liechtenstein', -160),
#  ('Aruba', -180),
#  ('Marshall Islands', -181),
#  ('American Samoa', -199),
#  ('Cook Islands', -236),
#  ('Saint Pierre and Miquelon', -242),
#  ('Niue', -260),
#  ('Saint Kitts and Nevis', -261),
#  ('Cayman Islands', -264),
#  ('Maldives', -298),
#  ('Malta', -316),
#  ('Grenada', -344),
#  ('Gaza Strip', -360),
#  ('Jan Mayen', -377),
#  ('Saint Vincent and the Grenadines', -389),
#  ('Heard Island and McDonald Islands', -412),
#  ('Barbados', -430),
#  ('Antigua and Barbuda', -442),
#  ('Curacao', -444),
#  ('Seychelles', -455),
#  ('Palau', -459),
#  ('Northern Mariana Islands', -464),
#  ('Andorra', -468),
#  ('Guam', -544),
#  ('Isle of Man', -572),
#  ('Saint Lucia', -596),
#  ('Singapore', -677),
#  ('Tonga', -687),
#  ('Micronesia, Federated States of', -702),
#  ('Dominica', -751),
#  ('Bahrain', -760),
#  ('Kiribati', -811),
#  ('Turks and Caicos Islands', -948),
#  ('Sao Tome and Principe', -964),
#  ('Hong Kong', -1038),
#  ('Faroe Islands', -1393),
#  ('Mauritius', -2020),
#  ('Comoros', -2235),
#  ('Luxembourg', -2586),
#  ('Samoa', -2811),
#  ('French Polynesia', -3487),
#  ('South Georgia and South Sandwich Islands', -3903),
#  ('Puerto Rico', -3949),
#  ('Cabo Verde', -4033),
#  ('Brunei', -4765),
#  ('Trinidad and Tobago', -5128),
#  ('West Bank', -5420),
#  ('Bahamas, The', -6140),
#  ('Gambia, The', -8940),
#  ('Cyprus', -9231),
#  ('Lebanon', -10060),
#  ('Jamaica', -10671),
#  ('Kosovo', -10887),
#  ('Qatar', -11586),
#  ('Falkland Islands (Islas Malvinas)', -12173),
#  ('Vanuatu', -12189),
#  ('Montenegro', -13092),
#  ('Timor-Leste', -14874),
#  ('Swaziland', -17044),
#  ('Kuwait', -17818),
#  ('New Caledonia', -17975),
#  ('Fiji', -18274),
#  ('Israel', -19890),
#  ('Slovenia', -20029),
#  ('Guinea-Bissau', -20115),
#  ('El Salvador', -20401),
#  ('Belize', -22646),
#  ('Rwanda', -22998),
#  ('Djibouti', -23160),
#  ('Burundi', -23530),
#  ('Macedonia', -25153),
#  ('Albania', -26048),
#  ('Netherlands', -26243),
#  ('Armenia', -26663),
#  ('Solomon Islands', -27076),
#  ('Haiti', -27370),
#  ('Equatorial Guinea', -28051),
#  ('Taiwan', -28540),
#  ('Belgium', -30028),
#  ('Lesotho', -30355),
#  ('Moldova', -31931),
#  ('Bhutan', -38394),
#  ('Switzerland', -38717),
#  ('Estonia', -39548),
#  ('Denmark', -41774),
#  ('Slovakia', -47175),
#  ('Dominican Republic', -47970),
#  ('Costa Rica', -51020),
#  ('Bosnia and Herzegovina', -51177),
#  ('Togo', -51985),
#  ('Croatia', -55354),
#  ('Latvia', -59909),
#  ('Lithuania', -60060),
#  ('Svalbard', -62045),
#  ('Sri Lanka', -63650),
#  ('Ireland', -67493),
#  ('Malawi', -69676),
#  ('Georgia', -69700),
#  ('Sierra Leone', -71500),
#  ('Panama', -73260),
#  ('Czech Republic', -75627),
#  ('Serbia', -77474),
#  ('Azerbaijan', -78658),
#  ('Austria', -81019),
#  ('Liberia', -81271),
#  ('United Arab Emirates', -83600),
#  ('Eritrea', -84400),
#  ('Hungary', -86188),
#  ('Jordan', -88262),
#  ('Portugal', -90850),
#  ('Korea, South', -94120),
#  ('Iceland', -97500),
#  ('Guatemala', -105429),
#  ('Bulgaria', -106099),
#  ('Benin', -108622),
#  ('Cuba', -108780),
#  ('Nicaragua', -109610),
#  ('Honduras', -111690),
#  ('Bangladesh', -111880),
#  ('Korea, North', -120278),
#  ('Greece', -129337),
#  ('Tajikistan', -138920),
#  ('Nepal', -139521),
#  ('Tunisia', -147110),
#  ('Suriname', -148180),
#  ('Uganda', -153162),
#  ('Cambodia', -171995),
#  ('Uruguay', -173815),
#  ('Guyana', -178729),
#  ('Syria', -182080),
#  ('Kyrgyzstan', -183651),
#  ('Senegal', -188338),
#  ('Belarus', -198200),
#  ('Ghana', -216533),
#  ('Romania', -221391),
#  ('Laos', -224800),
#  ('United Kingdom', -240250),
#  ('Guinea', -245577),
#  ('Gabon', -247667),
#  ('Western Sahara', -266000),
#  ('Finland', -269485),
#  ('Ecuador', -270121),
#  ('Burkina Faso', -273400),
#  ('Norway', -284762),
#  ('Italy', -286940),
#  ('Vietnam', -288930),
#  ('Poland', -295825),
#  ('Philippines', -296340),
#  ('Oman', -309500),
#  ("Cote d'Ivoire", -313543),
#  ('Malaysia', -327467),
#  ('Germany', -340322),
#  ('Congo, Republic of the', -341000),
#  ('Japan', -351055),
#  ('Sweden', -370375),
#  ('Zimbabwe', -382937),
#  ('Paraguay', -387852),
#  ('Uzbekistan', -403400),
#  ('Iraq', -436417),
#  ('Papua New Guinea', -442880),
#  ('Morocco', -446050),
#  ('Turkmenistan', -451760),
#  ('Cameroon', -469980),
#  ('Spain', -492590),
#  ('Thailand', -508660),
#  ('Yemen', -527968),
#  ('Botswana', -551730),
#  ('Ukraine', -555110),
#  ('Kenya', -557913),
#  ('Madagascar', -576039),
#  ('Somalia', -617017),
#  ('Central African Republic', -622984),
#  ('Burma', -630438),
#  ('France', -637053),
#  ('Afghanistan', -652230),
#  ('Chile', -731522),
#  ('Zambia', -734178),
#  ('Pakistan', -745655),
#  ('Turkey', -755702),
#  ('Mozambique', -773380),
#  ('Namibia', -822288),
#  ('Tanzania', -824300),
#  ('Venezuela', -852050),
#  ('Nigeria', -897768),
#  ('Colombia', -938490),
#  ('Egypt', -989450),
#  ('Mauritania', -1030700),
#  ('Bolivia', -1068021),
#  ('Mali', -1200188),
#  ('South Africa', -1209850),
#  ('Chad', -1234400),
#  ('Angola', -1246700),
#  ('Niger', -1266400),
#  ('Peru', -1274776),
#  ('Iran', -1414995),
#  ('Mongolia', -1542996),
#  ('Indonesia', -1718569),
#  ('Libya', -1759540),
#  ('Mexico', -1923515),
#  ('Saudi Arabia', -2149690),
#  ('Congo, Democratic Republic of the', -2189238),
#  ('Algeria', -2381741),
#  ('India', -2659123),
#  ('Kazakhstan', -2674500),
#  ('Argentina', -2692980),
#  ('Australia', -7623380),
#  ('Brazil', -8200510),
#  ('Canada', -8202344),
#  ('United States', -8497257),
#  ('China', -9055860),
#  ('Russia', -15657242),
#  ('Ethiopia', None),
#  ('New Zealand', None),
#  ('South Sudan', None),
#  ('Sudan', None),
#  ('European Union', None),
#  ('Greenland', None),
#  ('French Southern and Antarctic Lands', None),
#  ('Saint Barthelemy', None),
#  ('Saint Martin', None),
#  ('Akrotiri', None),
#  ('Dhekelia', None),
#  ('United States Pacific Island Wildlife Refuges', None),
#  ('Antarctica', None),
#  ('Arctic Ocean', None),
#  ('Atlantic Ocean', None),
#  ('Indian Ocean', None),
#  ('Pacific Ocean', None),
#  ('Southern Ocean', None)]

# %% [markdown]
# For the answer is "British Indian Ocean Territory" is the country that have more water than land.
